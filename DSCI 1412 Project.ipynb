# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy.csv')
df.head()
# Out:
#                 country  year  male_bmi   male_bp  male_expectancy  \
# 0           Afghanistan  1980      21.5  125.1991             37.8
# 1                Angola  1980      20.9  135.1761             39.6
# 2               Albania  1980      25.2  132.9270             68.0
# 3               Andorra  1980      25.7  140.8585             74.1
# 4  United Arab Emirates  1980      24.9  137.6991             66.9
#
#    female_bmi  female_bp  female_expectancy
# 0        20.4   122.0799               41.7
# 1        20.1   130.0896               45.6
# 2        25.2   132.2048               73.0
# 3        25.7   136.6040               80.4
# 4        27.2   134.5369               71.7

# %% [markdown]
# # Graphs for the United States [North America]

# %%
usa = df[df['country'] == 'United States']
usa.shape
# Out:
# (29, 8)

# %%
plt.scatter(usa['male_bp'], usa['male_expectancy'], color = 'Blue')
plt.scatter(usa['female_bp'], usa['female_expectancy'], color = 'Pink')
plt.xlabel('Blood Pressure')
plt.ylabel('Life Expectancy')
plt.title('Blood Pressure vs Life Expectancy - Americans')
# Out:
# Text(0.5, 1.0, 'Blood Pressure vs Life Expectancy - Americans')

# %%
np.cov(usa['male_bp'], usa['male_expectancy'])
# Out:
# array([[ 6.20125426, -4.11053361],
#        [-4.11053361,  2.91820197]])

# %%
np.cov(usa['female_bp'], usa['female_expectancy'])
# Out:
# array([[ 3.78987024, -1.56877612],
#        [-1.56877612,  0.68876847]])

# %%
corr_matrix=np.corrcoef(usa['male_bp'], usa['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(usa['female_bp'], usa['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.9662750392176057
# Male R^2=0.9336874514149854
# Female R=-0.9709842148824448
# Female R^2=0.9428103455508777

# %%
# https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/

plt.boxplot([usa['male_bp'], usa['female_bp']])
plt.xlabel('Sex')
plt.ylabel('Blood Pressure')
plt.title('Sex vs Blood Pressure - Americans')
# Out:
# Text(0.5, 1.0, 'Sex vs Blood Pressure - Americans')

# %%
plt.scatter(usa['male_bmi'], usa['male_bp'], color = 'Blue')
plt.scatter(usa['female_bmi'], usa['female_bp'], color = 'Pink')
plt.xlabel('Body Mass Index ')
plt.ylabel('Blood Pressure')
plt.title('Body Mass Index vs Blood Pressure - Americans')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Blood Pressure - Americans')

# %%
np.cov(usa['male_bmi'], usa['male_bp'])
# Out:
# array([[ 0.86206897, -2.2846572 ],
#        [-2.2846572 ,  6.20125426]])

# %%
np.cov(usa['female_bmi'], usa['female_bp'])
# Out:
# array([[ 1.07435961, -2.00186419],
#        [-2.00186419,  3.78987024]])

# %%
corr_matrix=np.corrcoef(usa['male_bmi'], usa['male_bp'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(usa['female_bmi'], usa['female_bp'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.9881213250266611
# Male R^2=0.9763837529724444
# Female R=-0.9920820781484969
# Female R^2=0.9842268497834403

# %%
plt.scatter(usa['male_bmi'], usa['male_expectancy'], color = 'Blue')
plt.scatter(usa['female_bmi'], usa['female_expectancy'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Life Expectancy')
plt.title('Body Mass Index vs Life Expectancy - Americans')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Life Expectancy - Americans')

# %%
np.cov(usa['male_bmi'], usa['male_expectancy'])
# Out:
# array([[0.86206897, 1.56831281],
#        [1.56831281, 2.91820197]])

# %%
np.cov(usa['female_bmi'], usa['female_expectancy'])
# Out:
# array([[1.07435961, 0.83996305],
#        [0.83996305, 0.68876847]])

# %%
corr_matrix=np.corrcoef(usa['male_bmi'], usa['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(usa['female_bmi'], usa['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=0.9887898748936947
# Male R^2=0.9777054166922885
# Female R=0.9764470967158517
# Female R^2=0.9534489326848159

# %%
plt.scatter(usa['year'], usa['male_expectancy'], color = 'Blue')
plt.scatter(usa['year'], usa['female_expectancy'], color = 'Pink')
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over The Years - Americans')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Over The Years - Americans')

# %%
np.cov(usa['male_expectancy'], usa['year'])
# Out:
# array([[ 2.91820197, 14.425     ],
#        [14.425     , 72.5       ]])

# %%
np.cov(usa['female_expectancy'], usa['year'])
# Out:
# array([[ 0.68876847,  6.925     ],
#        [ 6.925     , 72.5       ]])

# %% [markdown]
# # Graphs for the United Kingdom [Europe]

# %%
uk = df[df['country'] == 'United Kingdom']
uk.shape
# Out:
# (29, 8)

# %%
plt.scatter(uk['male_bp'], uk['male_expectancy'], color = 'Blue')
plt.scatter(uk['female_bp'], uk['female_expectancy'], color = 'Pink')
plt.xlabel('Blood Pressure')
plt.ylabel('Life Expectancy')
plt.title('Blood Pressure vs Life Expectancy - Brits')
# Out:
# Text(0.5, 1.0, 'Blood Pressure vs Life Expectancy - Brits')

# %%
np.cov(uk['male_bp'], uk['male_expectancy'])
# Out:
# array([[ 2.76324877, -2.96998021],
#        [-2.96998021,  4.58219212]])

# %%
np.cov(uk['female_expectancy'], uk['year'])
# Out:
# array([[ 2.3482266 , 12.99642857],
#        [12.99642857, 72.5       ]])

# %%
corr_matrix=np.corrcoef(uk['male_bp'], uk['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(uk['female_bp'], uk['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.8346548387249185
# Male R^2=0.6966486998069198
# Female R=-0.8450346172266914
# Female R^2=0.7140835043114608

# %%
# https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/

plt.boxplot([uk['male_bp'], uk['female_bp']])
plt.xlabel('Sex')
plt.ylabel('Blood Pressure')
plt.title('Sex vs Blood Pressure - Brits')
# Out:
# Text(0.5, 1.0, 'Sex vs Blood Pressure - Brits')

# %%
plt.scatter(uk['male_bmi'], uk['male_bp'], color = 'Blue')
plt.scatter(uk['female_bmi'], uk['female_bp'], color = 'Pink')
plt.xlabel('Body Mass Index ')
plt.ylabel('Blood Pressure')
plt.title('Body Mass Index vs Blood Pressure - Brits')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Blood Pressure - Brits')

# %%
np.cov(uk['male_bmi'], uk['male_bp'])
# Out:
# array([[ 0.70955665, -1.12613147],
#        [-1.12613147,  2.76324877]])

# %%
np.cov(uk['female_bmi'], uk['female_bp'])
# Out:
# array([[ 0.72096059, -1.6156415 ],
#        [-1.6156415 ,  5.43136965]])

# %%
corr_matrix=np.corrcoef(uk['male_bmi'], uk['male_bp'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(uk['female_bmi'], uk['female_bp'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.804239802748864
# Male R^2=0.6468016603255317
# Female R=-0.8164593316229029
# Female R^2=0.6666058401941173

# %%
plt.scatter(uk['male_bmi'], uk['male_expectancy'], color = 'Blue')
plt.scatter(uk['female_bmi'], uk['female_expectancy'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Life Expectancy')
plt.title('Body Mass Index vs Life Expectancy - Brits')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Life Expectancy - Brits')

# %%
np.cov(uk['male_bmi'], uk['male_expectancy'])
# Out:
# array([[0.70955665, 1.79605911],
#        [1.79605911, 4.58219212]])

# %%
np.cov(uk['female_bmi'], uk['female_expectancy'])
# Out:
# array([[0.72096059, 1.29241379],
#        [1.29241379, 2.3482266 ]])

# %%
corr_matrix=np.corrcoef(uk['male_bmi'], uk['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(uk['female_bmi'], uk['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=0.9960713347835787
# Male R^2=0.9921581039775401
# Female R=0.9932894426220183
# Female R^2=0.9866239168243599

# %%
plt.scatter(uk['year'], uk['male_expectancy'], color = 'Blue')
plt.scatter(uk['year'], uk['female_expectancy'], color = 'Pink')
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over The Years - Brits')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Over The Years - Brits')

# %%
np.cov(uk['male_expectancy'], uk['year'])
# Out:
# array([[ 4.58219212, 18.17142857],
#        [18.17142857, 72.5       ]])

# %%
np.cov(uk['female_expectancy'], uk['year'])
# Out:
# array([[ 2.3482266 , 12.99642857],
#        [12.99642857, 72.5       ]])

# %% [markdown]
# # Graphs for Japan [Asia]

# %%
japan = df[df['country'] == 'Japan']
japan.shape
# Out:
# (29, 8)

# %%
plt.scatter(japan['male_bp'], japan['male_expectancy'], color = 'Blue')
plt.scatter(japan['female_bp'], japan['female_expectancy'], color = 'Pink')
plt.xlabel('Blood Pressure')
plt.ylabel('Life Expectancy')
plt.title('Blood Pressure vs Life Expectancy - Japan')
# Out:
# Text(0.5, 1.0, 'Blood Pressure vs Life Expectancy - Japan')

# %%
np.cov(japan['male_bp'], japan['male_expectancy'])
# Out:
# array([[ 2.9837369 , -2.7376618 ],
#        [-2.7376618 ,  2.75591133]])

# %%
np.cov(japan['female_bp'], japan['female_expectancy'])
# Out:
# array([[ 6.96125245, -5.72301249],
#        [-5.72301249,  4.75423645]])

# %%
corr_matrix=np.corrcoef(japan['male_bp'], japan['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(japan['female_bp'], japan['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.9546999783521611
# Male R^2=0.9114520486656169
# Female R=-0.9948110779132446
# Female R^2=0.9896490807389117

# %%
# https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/

plt.boxplot([japan['male_bp'], japan['female_bp']])
plt.xlabel('Sex')
plt.ylabel('Blood Pressure')
plt.title('Sex vs Blood Pressure - Japan')
# Out:
# Text(0.5, 1.0, 'Sex vs Blood Pressure - Japan')

# %%
plt.scatter(japan['male_bmi'], japan['male_bp'], color = 'Blue')
plt.scatter(japan['female_bmi'], japan['female_bp'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Blood Pressure')
plt.title('Body Mass Index vs Blood Pressure - Japan')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Blood Pressure - Japan')

# %%
np.cov(japan['male_bmi'], japan['male_bp'])
# Out:
# array([[ 0.22714286, -0.72439679],
#        [-0.72439679,  2.9837369 ]])

# %%
np.cov(japan['female_bmi'], japan['female_bp'])
# Out:
# array([[ 0.04891626, -0.53526946],
#        [-0.53526946,  6.96125245]])

# %%
corr_matrix=np.corrcoef(japan['male_bmi'], japan['male_bp'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(japan['female_bmi'], japan['female_bp'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.8799271328770696
# Male R^2=0.7742717591732601
# Female R=-0.9172805113548372
# Female R^2=0.8414035365113917

# %%
plt.scatter(japan['male_bmi'], japan['male_expectancy'], color = 'Blue')
plt.scatter(japan['female_bmi'], japan['female_expectancy'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Life Expectancy')
plt.title('Body Mass Index vs Life Expectancy - Japan')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Life Expectancy - Japan')

# %%
np.cov(japan['male_bmi'], japan['male_expectancy'])
# Out:
# array([[0.22714286, 0.76464286],
#        [0.76464286, 2.75591133]])

# %%
np.cov(japan['female_bmi'], japan['female_expectancy'])
# Out:
# array([[0.04891626, 0.45533251],
#        [0.45533251, 4.75423645]])

# %%
corr_matrix=np.corrcoef(japan['male_bmi'], japan['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(japan['female_bmi'], japan['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=0.9664435093062702
# Male R^2=0.9340130566802188
# Female R=0.9441949372204795
# Female R^2=0.8915040794727853

# %%
plt.scatter(japan['year'], japan['male_expectancy'], color = 'Blue')
plt.scatter(japan['year'], japan['female_expectancy'], color = 'Pink')
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over The Years - Japan')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Over The Years - Japan')

# %%
np.cov(japan['male_expectancy'], japan['year'])
# Out:
# array([[ 2.75591133, 14.025     ],
#        [14.025     , 72.5       ]])

# %%
np.cov(japan['female_expectancy'], japan['year'])
# Out:
# array([[ 4.75423645, 18.47857143],
#        [18.47857143, 72.5       ]])

# %% [markdown]
# # Graphs for Argentina [South America]

# %%
arg = df[df['country'] == 'Saudi Arabia']
arg.shape
# Out:
# (29, 8)

# %%
plt.scatter(arg['male_bp'], arg['male_expectancy'], color = 'Blue')
plt.scatter(arg['female_bp'], arg['female_expectancy'], color = 'Pink')
plt.xlabel('Blood Pressure')
plt.ylabel('Life Expectancy')
plt.title('Blood Pressure vs Life Expectancy - Argentina')
# Out:
# Text(0.5, 1.0, 'Blood Pressure vs Life Expectancy - Argentina')

# %%
np.cov(arg['male_bp'], arg['male_expectancy'])
# Out:
# array([[ 7.30425395, -8.95831101],
#        [-8.95831101, 13.51862069]])

# %%
np.cov(arg['female_bp'], arg['female_expectancy'])
# Out:
# array([[  7.5422353 , -10.03811321],
#        [-10.03811321,  13.52857143]])

# %%
corr_matrix=np.corrcoef(arg['male_bp'], arg['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(arg['female_bp'], arg['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.9015130394807447
# Male R^2=0.8127257603538107
# Female R=-0.9937475738790639
# Female R^2=0.9875342405905255

# %%
# https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/

plt.boxplot([arg['male_bp'], arg['female_bp']])
plt.xlabel('Sex')
plt.ylabel('Blood Pressure')
plt.title('Sex vs Blood Pressure - Argentina')
# Out:
# Text(0.5, 1.0, 'Sex vs Blood Pressure - Argentina')

# %%
plt.scatter(arg['male_bmi'], arg['male_bp'], color = 'Blue')
plt.scatter(arg['female_bmi'], arg['female_bp'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Blood Pressure')
plt.title('Body Mass Index vs Blood Pressure - Argentina')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Blood Pressure - Argentina')

# %%
np.cov(arg['male_bmi'], arg['male_bp'])
# Out:
# array([[ 0.72      , -1.84442321],
#        [-1.84442321,  7.30425395]])

# %%
np.cov(arg['female_bmi'], arg['female_bp'])
# Out:
# array([[ 0.9076601, -2.4774548],
#        [-2.4774548,  7.5422353]])

# %%
corr_matrix=np.corrcoef(arg['male_bmi'], arg['male_bp'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(arg['female_bmi'], arg['female_bp'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.8042783893982536
# Male R^2=0.6468637276530488
# Female R=-0.9468781165661202
# Female R^2=0.8965781676318031

# %%
plt.scatter(arg['male_bmi'], arg['male_expectancy'], color = 'Blue')
plt.scatter(arg['female_bmi'], arg['female_expectancy'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Life Expectancy')
plt.title('Body Mass Index vs Life Expectancy - Argentina')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Life Expectancy - Argentina')

# %%
np.cov(arg['male_bmi'], arg['male_expectancy'])
# Out:
# array([[ 0.72      ,  3.04678571],
#        [ 3.04678571, 13.51862069]])

# %%
np.cov(arg['female_bmi'], arg['female_expectancy'])
# Out:
# array([[ 0.9076601 ,  3.38535714],
#        [ 3.38535714, 13.52857143]])

# %%
corr_matrix=np.corrcoef(arg['male_bmi'], arg['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(arg['female_bmi'], arg['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=0.9765836995870161
# Male R^2=0.9537157222990632
# Female R=0.9660884733647507
# Female R^2=0.9333269383682345

# %%
plt.scatter(arg['year'], arg['male_expectancy'], color = 'Blue')
plt.scatter(arg['year'], arg['female_expectancy'], color = 'Pink')
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over The Years - Argentina')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Over The Years - Argentina')

# %%
np.cov(arg['male_expectancy'], arg['year'])
# Out:
# array([[13.51862069, 30.95      ],
#        [30.95      , 72.5       ]])

# %%
np.cov(arg['female_expectancy'], arg['year'])
# Out:
# array([[13.52857143, 30.825     ],
#        [30.825     , 72.5       ]])

# %% [markdown]
# # Graphs for Libya [Africa]

# %%
libya = df[df['country'] == 'Libya']
libya.shape
# Out:
# (29, 8)

# %%
plt.scatter(libya['male_bp'], libya['male_expectancy'], color = 'blue')
plt.scatter(libya['female_bp'], libya['female_expectancy'], color = 'pink')
plt.xlabel('Blood Pressure')
plt.ylabel('Life Expectancy')
plt.title('Blood Pressure vs Life Expectancy - Libya')
# Out:
# Text(0.5, 1.0, 'Blood Pressure vs Life Expectancy - Libya')

# %%
np.cov(libya['male_bp'], libya['male_expectancy'])
# Out:
# array([[ 9.1007411 , -5.9283651 ],
#        [-5.9283651 ,  5.21948276]])

# %%
np.cov(libya['female_bp'], libya['female_expectancy'])
# Out:
# array([[ 3.42326226, -3.47670998],
#        [-3.47670998,  3.87662562]])

# %%
corr_matrix=np.corrcoef(libya['male_bp'], libya['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(libya['female_bp'], libya['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.8601671017329569
# Male R^2=0.7398874429036749
# Female R=-0.9543802579614532
# Female R^2=0.9108416767865699

# %%
# https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/

plt.boxplot([libya['male_bp'], libya['female_bp']])
plt.xlabel('Sex')
plt.ylabel('Blood Pressure')
plt.title('Sex vs Blood Pressure - Libya')
# Out:
# Text(0.5, 1.0, 'Sex vs Blood Pressure - Libya')

# %%
plt.scatter(libya['male_bmi'], libya['male_bp'], color = 'Blue')
plt.scatter(libya['female_bmi'], libya['female_bp'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Blood Pressure')
plt.title('Body Mass Index vs Blood Pressure - Libya')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Blood Pressure - Libya')

# %%
np.cov(libya['male_bmi'], libya['male_bp'])
# Out:
# array([[ 0.37963054, -1.21381935],
#        [-1.21381935,  9.1007411 ]])

# %%
np.cov(libya['female_bmi'], libya['female_bp'])
# Out:
# array([[ 0.49618227, -1.04538055],
#        [-1.04538055,  3.42326226]])

# %%
corr_matrix=np.corrcoef(libya['male_bmi'], libya['male_bp'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(libya['female_bmi'], libya['female_bp'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.6530329624906572
# Male R^2=0.42645205009932413
# Female R=-0.8021095961918222
# Female R^2=0.6433798043030081

# %%
plt.scatter(libya['male_bmi'], libya['male_expectancy'], color = 'Blue')
plt.scatter(libya['female_bmi'], libya['female_expectancy'], color = 'Pink')
plt.xlabel('Body Mass Index ')
plt.ylabel('Life Expectancy')
plt.title('Body Mass Index vs Life Expectancy - Libya')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Life Expectancy - Libya')

# %%
np.cov(libya['male_bmi'], libya['male_expectancy'])
# Out:
# array([[0.37963054, 1.30976601],
#        [1.30976601, 5.21948276]])

# %%
np.cov(libya['female_bmi'], libya['female_expectancy'])
# Out:
# array([[0.49618227, 1.2530665 ],
#        [1.2530665 , 3.87662562]])

# %%
corr_matrix=np.corrcoef(libya['male_bmi'], libya['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(libya['female_bmi'], libya['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=0.9304636462126871
# Male R^2=0.8657625969234085
# Female R=0.9034967001884514
# Female R^2=0.8163062872514204

# %%
plt.scatter(libya['year'], libya['male_expectancy'], color = 'Blue')
plt.scatter(libya['year'], libya['female_expectancy'], color = 'Pink')
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over The Years - Libya')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Over The Years - Libya')

# %%
np.cov(libya['male_expectancy'], libya['year'])
# Out:
# array([[ 5.21948276, 17.89285714],
#        [17.89285714, 72.5       ]])

# %%
np.cov(libya['female_expectancy'], libya['year'])
# Out:
# array([[ 3.87662562, 15.8       ],
#        [15.8       , 72.5       ]])

# %% [markdown]
# # Graphs for Australia

# %%
aussie = df[df['country'] == 'Australia']
aussie.shape
# Out:
# (29, 8)

# %%
plt.scatter(aussie['male_bp'], aussie['male_expectancy'], color = 'blue')
plt.scatter(aussie['female_bp'], aussie['female_expectancy'], color = 'pink')
plt.xlabel('Blood Pressure ')
plt.ylabel('Life Expectancy')
plt.title('Blood Pressure vs Life Expectancy - Australia')
# Out:
# Text(0.5, 1.0, 'Blood Pressure vs Life Expectancy - Australia')

# %%
np.cov(aussie['male_bp'], aussie['male_expectancy'])
# Out:
# array([[ 4.1511846 , -5.03716749],
#        [-5.03716749,  6.58778325]])

# %%
np.cov(aussie['female_bp'], aussie['female_expectancy'])
# Out:
# array([[11.99149695, -6.23392426],
#        [-6.23392426,  3.3032266 ]])

# %%
corr_matrix=np.corrcoef(aussie['male_bp'], aussie['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(aussie['female_bp'], aussie['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.9632315907422297
# Male R^2=0.9278150974038064
# Female R=-0.9905026394658877
# Female R^2=0.9810954787888903

# %%
# https://www.geeksforgeeks.org/box-plot-in-python-using-matplotlib/

plt.boxplot([aussie['male_bp'], aussie['female_bp']])
plt.xlabel('Sex')
plt.ylabel('Blood Pressure')
plt.title('Sex vs Blood Pressure - Australia')
# Out:
# Text(0.5, 1.0, 'Sex vs Blood Pressure - Australia')

# %%
plt.scatter(aussie['male_bmi'], aussie['male_bp'], color = 'Blue')
plt.scatter(aussie['female_bmi'], aussie['female_bp'], color = 'Pink')
plt.xlabel('Body Mass Index ')
plt.ylabel('Blood Pressure')
plt.title('Body Mass Index vs Blood Pressure - Australia')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Blood Pressure - Australia')

# %%
np.cov(aussie['male_bmi'], aussie['male_bp'])
# Out:
# array([[ 0.67137931, -1.60882277],
#        [-1.60882277,  4.1511846 ]])

# %%
np.cov(aussie['female_bmi'], aussie['female_bp'])
# Out:
# array([[ 0.99884236, -3.42856356],
#        [-3.42856356, 11.99149695]])

# %%
corr_matrix=np.corrcoef(aussie['male_bmi'], aussie['male_bp'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(aussie['female_bmi'], aussie['female_bp'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=-0.963691890934086
# Male R^2=0.9287020606521144
# Female R=-0.9906654730972495
# Female R^2=0.9814180795869972

# %%
plt.scatter(aussie['male_bmi'], aussie['male_expectancy'], color = 'Blue')
plt.scatter(aussie['female_bmi'], aussie['female_expectancy'], color = 'Pink')
plt.xlabel('Body Mass Index')
plt.ylabel('Life Expectancy')
plt.title('Body Mass Index vs Life Expectancy - Australia')
# Out:
# Text(0.5, 1.0, 'Body Mass Index vs Life Expectancy - Australia')

# %%
np.cov(aussie['male_bmi'], aussie['male_expectancy'])
# Out:
# array([[0.67137931, 2.09305419],
#        [2.09305419, 6.58778325]])

# %%
np.cov(aussie['female_bmi'], aussie['female_expectancy'])
# Out:
# array([[0.99884236, 1.80518473],
#        [1.80518473, 3.3032266 ]])

# %%
corr_matrix=np.corrcoef(aussie['male_bmi'], aussie['male_expectancy'])
corr = corr_matrix[0,1]
print(f"Male R={corr}")
R_sq = corr**2
 
print(f"Male R^2={R_sq}")
corr_matrix=np.corrcoef(aussie['female_bmi'], aussie['female_expectancy'])
corr = corr_matrix[0,1]
print(f"Female R={corr}")
R_sq = corr**2
 
print(f"Female R^2={R_sq}")
# Out:
# Male R=0.9952377581412756
# Male R^2=0.9904981952300721
# Female R=0.9938114367461754
# Female R^2=0.9876611718074975

# %%
plt.scatter(aussie['year'], aussie['male_expectancy'], color = 'Blue')
plt.scatter(aussie['year'], aussie['female_expectancy'], color = 'Pink')
plt.xlabel('Years')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over The Years - Australia')
# Out:
# Text(0.5, 1.0, 'Life Expectancy Over The Years - Australia')

# %%
np.cov(aussie['male_expectancy'], aussie['year'])
# Out:
# array([[ 6.58778325, 21.79285714],
#        [21.79285714, 72.5       ]])

# %%
np.cov(aussie['female_expectancy'], aussie['year'])
# Out:
# array([[ 3.3032266, 15.4      ],
#        [15.4      , 72.5      ]])

# %% [markdown]
# # Do Certain Regions Have Higer/Lower Life Expectancies?

# %%
selected_countries = ['United States', 'Mexico', 'United Kingdom', 'France', 'Germany', 'Japan', 'China', 'Libya', 'Nigeria', 'South Africa', 'Ghana', 'Australia', 'Argentina', 'Brazil']

# %%
df2 = df[df['country'].isin(selected_countries)]

sns.scatterplot(data = df2, x = "year", y = "male_expectancy", hue = 'country')

plt.title('Which Regions Have Better Health Care?')
plt.show()

# %%
sns.scatterplot(data = df2, x = "year", y = "female_expectancy", hue = 'country')

plt.title('Which Regions Have Better Health Care?')
plt.show()

# %%
plt.scatter(aussie['male_bp'], aussie['male_expectancy'], color = 'blue')
plt.scatter(aussie['female_bp'], aussie['female_expectancy'], color = 'pink')
plt.xlabel('Blood Pressure ')
plt.ylabel('Life Expectancy')
plt.title('Blood Pressure vs Life Expectancy - Australia')
# Out:
# Text(0.5, 1.0, 'Blood Pressure vs Life Expectancy - Australia')

# %%
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
 
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
 
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
 
    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
 
    return (b_0, b_1)
b=estimate_coef(aussie['female_bp'], aussie['female_expectancy'])
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
 
    # predicted response vector
    y_pred = b[0] + b[1]*x
 
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
 
    # putting labels
    
    plt.xlabel('Blood Pressure')
    plt.ylabel('Life Expectancy')
    plt.title('Blood Pressure vs Life Expectancy - Australian Females')
 
    # function to show plot
    plt.show()
plot_regression_line(aussie['female_bp'], aussie['female_expectancy'], b)

# %%
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
 
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
 
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
 
    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
 
    return (b_0, b_1)
b=estimate_coef(aussie['female_bmi'], aussie['female_expectancy'])
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
 
    # predicted response vector
    y_pred = b[0] + b[1]*x
 
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
 
    # putting labels
    
    plt.xlabel('BMI')
    plt.ylabel('Life Expectancy')
    plt.title('BMI vs Life Expectancy - Australian Females')
 
    # function to show plot
    plt.show()
plot_regression_line(aussie['female_bmi'], aussie['female_expectancy'], b)

# %%
def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)
 
    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)
 
    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
 
    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
 
    return (b_0, b_1)
b=estimate_coef(aussie['female_bmi'], aussie['female_bp'])
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
 
    # predicted response vector
    y_pred = b[0] + b[1]*x
 
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
 
    # putting labels
    
    plt.xlabel('BMI')
    plt.ylabel('Blood Pressure')
    plt.title('BMI vs Blood Pressure - Australian Females')
 
    # function to show plot
    plt.show()
plot_regression_line(aussie['female_bmi'], aussie['female_bp'], b)

# %%
# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_male.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1980

# Filter the data for the year 1980
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for males in the year 1980:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1980:", variance)
# Out:
# Mean life expectancy for males in the year 1980: 60.23516949152538
# Variance in the year 1980: 91.75922592859719

# %%
# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_male.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1990

# Filter the data for the year 1990
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for males in the year 1990:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1990:", variance)
# Out:
# Mean life expectancy for males in the year 1990: 63.13644067796604
# Variance in the year 1990: 89.01721961774247

# %%
# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_male.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2000

# Filter the data for the year 2000
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for males in the year 2000:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2000:", variance)
# Out:
# Mean life expectancy for males in the year 2000: 65.57669491525424
# Variance in the year 2000: 85.38060349801653

# %%
# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_male.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2008

# Filter the data for the year 2008
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for males in the year 2008:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2008:", variance)
# Out:
# Mean life expectancy for males in the year 2008: 68.09491525423729
# Variance in the year 2008: 72.96286765236201

# %%
# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_female.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1980

# Filter the data for the year 1980
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for females in the year 1980:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1980:", variance)
# Out:
# Mean life expectancy for females in the year 1980: 65.65805084745757
# Variance in the year 1980: 107.2433817165525

# %%
# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_female.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1990

# Filter the data for the year 1990
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for females in the year 1990:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1990:", variance)
# Out:
# Mean life expectancy for females in the year 1990: 68.66991525423728
# Variance in the year 1990: 104.08023999278764

# %%
import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_female.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2000

# Filter the data for the year 2000
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for females in the year 2000:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2000:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/life_expectancy_female.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2008

# Filter the data for the year 2008
filtered_df = df[year_column]

# Calculate the mean life expectancy
mean_life_expectancy = filtered_df.mean()

# Print the mean life expectancy
print("Mean life expectancy for females in the year 2008:", mean_life_expectancy)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2008:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP men mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '1980'

# Filter the data for the year 1980
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1980:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1980:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP men mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '1990'

# Filter the data for the year 1990
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1990:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1990:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP men mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '2000'

# Filter the data for the year 2000
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2000:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2000:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP men mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '2008'

# Filter the data for the year 2008
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2008:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2008:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP women mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '1980'

# Filter the data for the year 1980
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1980:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1980:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP women mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '1990'

# Filter the data for the year 1990
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1990:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1990:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP women mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '2000'

# Filter the data for the year 2000
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2000:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2000:", variance)

import pandas as pd

# Load the CSV file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/Blood pressure SBP women mmHg.csv"
df = pd.read_csv(file_path)

# Specify the column name
year_column = '2008'

# Filter the data for the year 2008
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2008:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2008:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_men_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1980

# Filter the data for the year 1980
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1980:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1980:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_men_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1990

# Filter the data for the year 1990
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1990:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1990:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_men_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2000

# Filter the data for the year 2000
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2000:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2000:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_men_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2008

# Filter the data for the year 2008
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2008:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2008:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_women_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1980

# Filter the data for the year 1980
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1980:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1980:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_women_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 1990

# Filter the data for the year 1990
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 1990:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 1990:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_women_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2000

# Filter the data for the year 2000
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2000:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2000:", variance)


import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_women_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2008

# Filter the data for the year 2008
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2008:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2008:", variance)

import pandas as pd

# Load the Excel file
file_path = "C:/Users/saad2/OneDrive - aucegypt.edu/Desktop/DSCI 1412/Project/Dataset7/body_mass_index_bmi_women_kgperm2.xlsx"
df = pd.read_excel(file_path)

# Specify the column name
year_column = 2008

# Filter the data for the year 2008
filtered_df = df[year_column]

# Calculate the mean value
mean_value = filtered_df.mean()

# Print the mean value
print("Mean value in the year 2008:", mean_value)

# Calculate the variance
variance = filtered_df.var()

# Print the variance
print("Variance in the year 2008:", variance)
# Out:
# Mean life expectancy for females in the year 2000: 70.76398305084743
# Variance in the year 2000: 103.63627172737102
# Mean life expectancy for females in the year 2008: 73.26398305084743
# Variance in the year 2008: 88.18801640822215
# Mean value in the year 1980: 132.6170673366835
# Variance in the year 1980: 23.998400041301466
# Mean value in the year 1990: 130.78021055276372
# Variance in the year 1990: 17.552462429231507
# Mean value in the year 2000: 130.0858246231155
# Variance in the year 2000: 11.768632314491647
# Mean value in the year 2008: 131.18050301507537
# Variance in the year 2008: 12.79681924978884
# Mean value in the year 1980: 128.5102110552763
# Variance in the year 1980: 30.090226108564032
# Mean value in the year 1990: 127.7096386934673
# Variance in the year 1990: 17.577918699353848
# Mean value in the year 2000: 126.76872060301511
# Variance in the year 2000: 13.12753383447236
# Mean value in the year 2008: 126.48543618090456
# ...
